# %%
from qiskit import QuantumCircuit


qc= QuantumCircuit(2)

qc.h(0)
qc.cx(0, 1)

qc.draw(output = 'mpl')
# Out:
# ---------------------------------------------------------------------------
# MissingOptionalLibraryError               Traceback (most recent call last)
# Cell In[5], line 9
#       6 qc.h(0)
#       7 qc.cx(0, 1)
# ----> 9 qc.draw(output = 'mpl')
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/qiskit/circuit/quantumcircuit.py:3808, in QuantumCircuit.draw(self, output, scale, filename, style, interactive, plot_barriers, reverse_bits, justify, vertical_compression, idle_wires, with_layout, fold, ax, initial_state, cregbundle, wire_order, expr_len)
#    3805 # pylint: disable=cyclic-import
#    3806 from qiskit.visualization import circuit_drawer
# -> 3808 return circuit_drawer(
#    3809     self,
#    3810     scale=scale,
#    3811     filename=filename,
#    3812     style=style,
#    3813     output=output,
#    3814     interactive=interactive,
#    3815     plot_barriers=plot_barriers,
#    3816     reverse_bits=reverse_bits,
#    3817     justify=justify,
# ...
